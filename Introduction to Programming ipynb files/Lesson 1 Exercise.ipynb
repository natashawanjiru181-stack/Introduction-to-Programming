# %%
#Day 2: 30 days of python
#First name
first_name=('Tash')
print(first_name)
# Out:
# Tash

# %%
#Last name
last_name=('Gicheha')
print(last_name)
# Out:
# Gicheha

# %%
#My full name
full_name=('Tash Wanjiru Gicheha')
print(full_name)
# Out:
# Tash Wanjiru Gicheha

# %%
#Country I grew up in
country=('Kenya')
print(country)
# Out:
# Kenya

# %%
#City I live in
city=('Kiambu')
print(city)
# Out:
# Kiambu

# %%
#My father's age
age=('47 years')
print(age)
# Out:
# 47 years

# %%
#Year i was born
year=(2006)
print(year)
# Out:
# 2006

# %%
#Informing you whether i'm married or not
is_married=input('Are you married?')
print(is_married)
# Out:
# No i'm not

# %%
#Telling you my truth
is_true=input('Are you a Christian')
print(is_true)
# Out:
# Yes I am

# %%
#Hardest course
is_light_on=('Chinese requires one to practice everyday')
print(is_light_on)
# Out:
# Chinese requires one to practice everyday

# %%
#Having multiple variables in one line
#Can have may quotes if its print only
color, number, cousin=('Pink', 'Seven', 'Fiona')
print(color, number, cousin)
# Out:
# Pink Seven Fiona
