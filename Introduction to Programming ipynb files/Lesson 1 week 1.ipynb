# %%
print("hello world")
# Out:
# hello world

# %%
if 5>2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
print(5>2)
# Out:
# True

# %%
if 5>2:
 print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5>2:
print("Five is greater than two!")
# Out:
#   Cell In[5], line 2
#     print("Five is greater than two!")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
#This is a comment.
print("Hello, World!")
# Out:
# Hello, World!

# %%
#Variables
x=5
y="John"
print(x)
print(y)
# Out:
# 5
# John

# %%
#Numeric types-Int,str and float
X=4
Y='shahid'
Z=5.987

print(type(x))
print(type(y))
print(type(Z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
#Type Conversion
x=3
y=2.8
z=1j

#Convert from int to float
a=float(x)

#Convert from float to int
b=int(y)

#Convert from int to complex
c=complex(x)

print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 3.0
# 2
# (3+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
#Float
x=1.10
y=1.7
z=-35.36


print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
#Using triple quotes
c='''Natasha is spectacular'''
print(c)
# Out:
# Natasha is spectacular

# %%
#Nicknames
HOTSTUFF=('Tash, Tasha, Tashy, Nat, Ash, Dude, Sha')
print(HOTSTUFF)
# Out:
# Tash, Tasha, Tashy, Nat, Ash, Dude, Sha

# %%
#Slicing strings
b='Hello, World!'
s=b[2:5]
print(s)
# Out:
# llo

# %%
#Slicing strings to get the first 5 characters

# %%
#Slicing strings to get the first 5 characters
d='OrangeBigger'
e=d[:5]
print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2 d='OrangeBigger'
#       3 e=d[:5]
# ----> 4 print(d)
#
# TypeError: 'str' object is not callable

# %%
#Last 5 characters
a='When in need, reach out'
print(a[5:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 #Last 5 characters
#       2 a='When in need, reach out'
# ----> 3 print(a[5:])
#
# TypeError: 'str' object is not callable

# %%
#Get charaters from index 2 - index 7
a='When in need, reach out'
b=a[2:7]
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 a='When in need, reach out'
#       3 b=a[2:7]
# ----> 4 print(b)
#
# TypeError: 'str' object is not callable

# %%
#Reverse string using slicing
a='My, World'
b=a.replace('W','M')
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 a='My, World'
#       3 b=a.replace('W','M')
# ----> 4 print(b)
#
# TypeError: 'str' object is not callable
