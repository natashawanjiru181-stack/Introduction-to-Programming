# %%
#Assigning a single value to several variables simultaneously
a=b=c=4
print(a,b,c)
# Out:
# 4 4 4

# %%
#Testing variable names - variable names can be anything
ceaser='intelligent'
print(ceaser)
# Out:
# intelligent

# %%
#Using dash in variable
Sun_hi=5**2
print(Sun_hi)
# Out:
# 25

# %%
#Capital letters in variable
GYAT=15%2
print(GYAT)
# Out:
# 1

# %%
#Use a number at the end of variable
FIFA2025=300//4
print(FIFA2025)
# Out:
# 75

# %%
#Type conversion 
#What we are using
GYAL=7 #Int
RUSH=3.4 #Float
YO=4j #Complex
print(GYAL, RUSH, YO)
# Out:
# 7 3.4 4j

# %%
#Convert float into int
a1=int(RUSH)
print(a1)
print(type(a1))
# Out:
# 3
# <class 'int'>

# %%
#Convert int to complex
#Start with what you want as result
w_=complex(GYAL)
print(w_)
print(type(w_))
# Out:
# (7+0j)
# <class 'complex'>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
