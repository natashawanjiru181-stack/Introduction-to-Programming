# %%
#1. Enter name and age then print
name=str(input('What is your name?'))
print(name)

age=str(input('How old are you?:'))
print(age)
# Out:
# Kim Kardashian
# 28

# %%
#Print a message using both values
#I created a dictionary
mess={'Kim Kardashian':28}
print(mess)
# Out:
# {'Kim Kardashian': 28}

# %%
#2. Loops and conditions
#Write an integer input
integer=int(input('Enter integer:'))
print(integer)
# Out:
# 78

# %%
#Loop from one to the integer
for i in range(1, integer + 1):
#Test whether the number is even or odd
#Use if and else statements
   if integer %2 ==0:
    print('even number')
   else:
    print('odd number')
# Out:
# even number

# %%
#3. Lists and strings
#Get values of the list from user input
num=(input('List of numbers:'))#Numbers are separated by spaces
print(num)
# Out:
# 10 20 30 40 50 60 70 80

# %%
#Create the list using the values above
#Use split method
list=num.split()
print(list)#Assumed numbers were strings
# Out:
# ['10', '20', '30', '40', '50', '60', '70', '80']

# %%
#Convert every string item in the list to an integer
integers=[int(num) for num in list]#num is a temporary variable, can only use that word
print(integers)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
#4. Dictionaries
#Creating a dictionary of student names and scores
names_scores={'Tashy':100, 'Caroline':98, 'Ceaser':34, 'Isaac':45}
print(names_scores)
# Out:
# {'Tashy': 100, 'Caroline': 98, 'Ceaser': 34, 'Isaac': 45}

# %%
#Checking if a specific student exists
#Using if statements
if 'Tashy' in names_scores:
    print('true')
else:
    print('false')
# Out:
# true

# %%
#5. Sets
#List of course names with duplicates
list=['Data Science and Analytics', 'Nursing', 'Engineering', 'Medicine', 'Nursing', 'Engineering']
print(list)#Nursing and Engineering are the duplicates
# Out:
# ['Data Science and Analytics', 'Nursing', 'Engineering', 'Medicine', 'Nursing', 'Engineering']

# %%
#Convert the list into a set
new=set(list)
print(new)#Unique course names
# Out:
# {'Data Science and Analytics', 'Nursing', 'Engineering', 'Medicine'}

# %%
#6. Problem Breakdown
#Create a sentence as input
sen=str(input('Take a sentence as input:'))
print(sen)
# Out:
# Why does everything have to be soo hard, I have nobody to rely on

# %%
#Count how many words are longer than 5 characters
brek=br(sen)
print(brek)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #Break sentence into words
# ----> 2 brek=br(sen)
#       3 print(brek)
#
# NameError: name 'br' is not defined

# %%
#7. Debugging
#Write 2 numbers using user input
first=int(input('First number:'))
print(first)

second=int(input('Second number:'))
print(second)
# Out:
# 56
# 2

# %%
#Divide the two numbers above
div=first/second
print(div)
# Out:
# 28.0
