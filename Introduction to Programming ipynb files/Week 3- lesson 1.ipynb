# %%
#Change lower case to upper case
a='free booze'
B=a.upper()
print(B)
# Out:
# FREE BOOZE

# %%
#Change upper case to lower case
C='MY SUNSHINE'
d=C.lower()
print(d)
# Out:
# my sunshine

# %%
#Replace my string - replacing S with M
C= 'My Sunshine'
D=C.replace('S','M')
print(D)
# Out:
# My Munshine

# %%
#String Concatenation/ String Combination
a='World'
b='Cup'
d=a+b
print(d)
# Out:
# WorldCup

# %%
#String format
age=36 
txt='My name is John and I am {}'
D=txt.format(age)
print(D)
# Out:
# My name is John and I am 36

# %%
#Add 2 numbers with user input
#Store input numbers
a=input('Enter first number:')
b=input('Enter second number')

#Add the 2 numbers
#Float has a decimal point
c=float(a) + float(b)

#Display sum
print('The sum of {0} and {1} is {2}'.format(a,b,c))
# Out:
# The sum of 67.4 and 89.8 is 157.2

# %%
#Cube of a number using python program
no=int(int())

# %%
#List indexing and splitting
#When counting index the first digit is zero, ignore the last index based on question
#1. Write the list
#Values are in curly brackets
list=[1,2,3,4,5,6,7]
print(list[0])
print(list[1])
print(list[2])
print(list[3])

#Slice the elements
#Prints all elements between index 2 and index 5
print(list[2:5])

#Start with 1 end with 7 skip by 2
print(list[1:6:2])
# Out:
# 1
# 2
# 3
# 4
# [3, 4, 5]
# [2, 4, 6]

# %%
#Negative indexing
#Negative indices are counted from the right
#Last element on your right has the index -1 always
