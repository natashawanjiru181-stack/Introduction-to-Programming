# %%
#if statements
#from slide 122
a=67
b=67
if b>a:#if statement has to be written with print
 print('b is greater than a')#if there is no output, statement is false
#If  there is no indent after clicking shift tab in the space, you get an error

# %%
#Elif keyword
a=33
b=33
if b>a:
 print('b is greater than a')
elif a==b:
    print('a and b are equal')
# Out:
# a and b are equal

# %%
#Else keyword
a=200
b=33
if b>a:
    print('b is greater than a')
else: #if statement has to be there to avoid errors
    print('a is greater than b')
# Out:
# a is greater than b

# %%
#Short hand if
#if you have one statement everything is executed in one line
if a>b:print('a is greater than b')
# Out:
# a is greater than b

# %%
#Short hand if else
#if and else statements in one line
a=22
b=400
print('A') if a>b else print('B') #don't add the word or
# Out:
# B

# %%
#Multiple else statements on the same line
print('A') if a>b else print('=') if a == b else print('B')
# Out:
# B

# %%
#And statement
#Combines conditional statements
a=200
b=88
c=5000
if a>b and c>a:#Testing if 2 conditions are true
    print('Both conditions are True')
# Out:
# Both conditions are True

# %%
#Or statement
#Tests if at least one condition is true

# %%
#Nested if
#This is an if statement inside an if statement
x=41
if x>10:
    print('above 10,')
    if x>20:
         print('also above 20!')
    else:
         print('not above 20.')#this wasn't printed because statement is false
# Out:
# above 10,
# also above 20!

# %%
#Check if no is positive
num=float(input('Enter a number:'))#My number was 34
if num>=0:
    if num==0:
        print('Zero')#statement is false
    else:
        print('positive number')#true statement
else:
    print('negative number')#false statement
# Out:
# positive number

# %%
#Pass statement
#if your statement has no content put it in a pass statement
a=56
b=900
if b > a:#there is no print
 pass

# %%
#Using if statement in lists
list=[3,4,5,6,7]
if list[0] > list[1]:#list 0 is value in index 1, list 1 is value in index 2
 print('success')#3 is not greater than 4
else:
    print('hello')#true statement
# Out:
# hello
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
