# %%
# Dictionaries
person = {"name": "Alice", "age": 25, "city": "Nairobi"}

print(person["name"])        # Access value

person["job"] = "Engineer"   # Add key-value
print(person)

print(person.get("age"))     # Get value safely
# Out:
# Alice
# {'name': 'Alice', 'age': 25, 'city': 'Nairobi', 'job': 'Engineer'}
# 25

# %%
# Testing multiline string
# has to be in print/ a variable
print('''Natasha is taking her university studies seriously.
Natasha really wants to have the skills of a Data Scientist.
She does not give up when things get hard.''')
# Out:
# Natasha is taking her university studies seriously.
# Natasha really wants to have the skills of a Data Scientist.
# She does not give up when things get hard.

# %%
# Exercise
# 1. Create an empty dictionary called dog
dog={}
print(dog)
# Out:
# {}

# %%
# i)  Using dict() constructor
dog = dict()
print(dog)  # Output: {}
# Out:
# {}

# %%
# 2. Add name, color, breed, legs, age to the dog dictionary
dog={'name':'Pookie', 'color':'Black', 'breed':'Bernese Mountain Dog', 'legs':4, 'age':'2 years old'}
print(dog)
# Out:
# {'name': 'Pookie', 'color': 'Black', 'breed': 'Bernese Mountain Dog', 'legs': 4, 'age': '2 years old'}

# %%
# 3. Create a student dictionary and 
# add first_name, last_name, gender, age, marital status, skills, country, city and address as keys for the dictionary
student_dictionary={'first_name':'Geneviv', 'last_name':'Gicheha', 'gender':'prefer not to say', 'age':'75 years old', 'marital status':'2 husbands', 'skills':'Poker and Seduction', 'country':'Indonesia', 'city':'Jakarta', 'address':'6452-Sunshine Street'}
print(student_dictionary)
# Out:
# {'first_name': 'Geneviv', 'last_name': 'Gicheha', 'gender': 'prefer not to say', 'age': '75 years old', 'marital status': '2 husbands', 'skills': 'Poker and Seduction', 'country': 'Indonesia', 'city': 'Jakarta', 'address': '6452-Sunshine Street'}

# %%
# 4. Get the length of the student dictionary
a=len(student_dictionary)
print(f'{a} key-value pairs')
# Out:
# 9 key-value pairs

# %%
# 5. Get the value of skills 
# and check the data type, it should be a list
